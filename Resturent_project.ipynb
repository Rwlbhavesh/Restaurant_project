# %%
# problme  = create a item order menu digital condition is 
# 1. show first welcom for customer after show all availeble menu
# 2. second this customer input your order and after saying this any add another item ?
# 3 and last one total bill and thanku greeting print

# %%
# logic this code :-
# first create a menu

# %%
menu = {
    "Espresso": 60,
    "Cappuccino": 80,
    "Latte": 90,
    "Americano": 70,
    "Mocha": 100,
    "Black Coffee": 50,
    "Cold Coffee": 95,
    "Iced Latte": 105,
    "Hot Chocolate": 110,
    "Green Tea": 55,
    "Masala Chai": 40,
    "Lemon Tea": 45,
    "Ginger Tea": 50,
    "Burger": 120,
    "Cheese Burger": 140,
    "Veg Sandwich": 80,
    "Grilled Sandwich": 100,
    "Paneer Sandwich": 110,
    "Club Sandwich": 130,
    "Fries": 70,
    "Cheesy Fries": 90,
    "Pasta White Sauce": 150,
    "Pasta Red Sauce": 150,
    "Pizza Margherita": 160,
    "Pizza Farmhouse": 180,
    "Pizza Peppy Paneer": 200,
    "Garlic Bread": 80,
    "Cheesy Garlic Bread": 100,
    "Spring Rolls": 90,
    "Manchurian Dry": 110,
    "Noodles": 100,
    "Hakka Noodles": 110,
    "Fried Rice": 100,
    "Veg Biryani": 120,
    "Paneer Biryani": 140,
    "Dal Fry": 90,
    "Jeera Rice": 70,
    "Veg Thali": 180,
    "Paneer Thali": 200,
    "Lassi Sweet": 60,
    "Lassi Salted": 55,
    "Cold Drink": 40,
    "Water Bottle": 20,
    "Ice Cream Vanilla": 50,
    "Ice Cream Chocolate": 60,
    "Brownie": 80,
    "Mojito": 90,
    "Fruit Juice": 70,
    "Milkshake": 100
       }

# %%
# second this is print a welcom and menu to see this customer

# %%
print ("Welcom to XYZ INDIAN resturent\ncan i help you")
print ("""
          
    "Espresso": 60,
    "Cappuccino": 80,
    "Latte": 90,
    "Americano": 70,
    "Mocha": 100,
    "Black Coffee": 50,
    "Cold Coffee": 95,
    "Iced Latte": 105,
    "Hot Chocolate": 110,
    "Green Tea": 55,
    "Masala Chai": 40,
    "Lemon Tea": 45,
    "Ginger Tea": 50,
    "Burger": 120,
    "Cheese Burger": 140,
    "Veg Sandwich": 80,
    "Grilled Sandwich": 100,
    "Paneer Sandwich": 110,
    "Club Sandwich": 130,
    "Fries": 70,
    "Cheesy Fries": 90,
    "Pasta White Sauce": 150,
    "Pasta Red Sauce": 150,
    "Pizza Margherita": 160,
    "Pizza Farmhouse": 180,
    "Pizza Peppy Paneer": 200,
    "Garlic Bread": 80,
    "Cheesy Garlic Bread": 100,
    "Spring Rolls": 90,
    "Manchurian Dry": 110,
    "Noodles": 100,
    "Hakka Noodles": 110,
    "Fried Rice": 100,
    "Veg Biryani": 120,
    "Paneer Biryani": 140,
    "Dal Fry": 90,
    "Jeera Rice": 70,
    "Veg Thali": 180,
    "Paneer Thali": 200,
    "Lassi Sweet": 60,
    "Lassi Salted": 55,
    "Cold Drink": 40,
    "Water Bottle": 20,
    "Ice Cream Vanilla": 50,
    "Ice Cream Chocolate": 60,
    "Brownie": 80,
    "Mojito": 90,
    "Fruit Juice": 70,
    "Milkshake": 100
        
        """)
# create a variable for store customer order 

order_total = 0

# after create a varible so customer input your order 
# add check this item available in menu

item_1 = input("enter your order for this menu:- ")
if item_1 in menu:
    order_total += menu[item_1]
    print ("this item selected",{item_1},"for your order")
else:
    print ("this item is not available for this resturant ,sorry for this")

# after add more variable for asking another add item 

another_item = input ("do you want any another item : yes/no ?")
if another_item == "yes":
    item_2 = input("please enter your item:- ")
    if item_2 in menu:
        order_total += menu[item_2]
        print ("thanku for order, please wait 5 to 10 minits your order after ready")
    else:
        print("your add item is not availabel, sorry for this")

# last one total patment add and show 
# and customer feedback for this resturent 
        
print ("your total payment is")
print (order_total)
print ("THANKU FOR VISIT OUR RESTURENT")
# Out:
# Welcom to XYZ INDIAN resturent
# can i help you
#
#
#     "Espresso": 60,
#     "Cappuccino": 80,
#     "Latte": 90,
#     "Americano": 70,
#     "Mocha": 100,
#     "Black Coffee": 50,
#     "Cold Coffee": 95,
#     "Iced Latte": 105,
#     "Hot Chocolate": 110,
#     "Green Tea": 55,
#     "Masala Chai": 40,
#     "Lemon Tea": 45,
#     "Ginger Tea": 50,
#     "Burger": 120,
#     "Cheese Burger": 140,
#     "Veg Sandwich": 80,
#     "Grilled Sandwich": 100,
#     "Paneer Sandwich": 110,
#     "Club Sandwich": 130,
#     "Fries": 70,
#     "Cheesy Fries": 90,
#     "Pasta White Sauce": 150,
#     "Pasta Red Sauce": 150,
#     "Pizza Margherita": 160,
#     "Pizza Farmhouse": 180,
#     "Pizza Peppy Paneer": 200,
#     "Garlic Bread": 80,
#     "Cheesy Garlic Bread": 100,
#     "Spring Rolls": 90,
#     "Manchurian Dry": 110,
#     "Noodles": 100,
#     "Hakka Noodles": 110,
#     "Fried Rice": 100,
#     "Veg Biryani": 120,
#     "Paneer Biryani": 140,
#     "Dal Fry": 90,
# ...
